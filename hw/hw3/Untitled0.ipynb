# %%
import pandas as pd

inputfile = 'auto_mpg.txt'

# %%
df = pd.read_table(inputfile, sep='|')

# %%
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0   18          8           307         130    3504          12.0          70
# 1   15          8           350         165    3693          11.5          70
# 2   18          8           318         150    3436          11.0          70
# 3   16          8           304         150    3433          12.0          70
# 4   17          8           302         140    3449          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#
# [5 rows x 9 columns]

# %%
df.groupby(['model_year', 'mpg']).mean().sort(ascending=True).tail(20)
# Out:
#                  cylinders  displacement  horsepower       weight  \
# model_year mpg
# 81         34.7        4.0    105.000000   63.000000  2215.000000
#            35.1        4.0     81.000000   60.000000  1760.000000
#            37.0        4.0     85.000000   65.000000  1975.000000
#            37.7        4.0     89.000000   62.000000  2050.000000
#            39.0        4.0     86.000000   64.000000  1875.000000
#            39.1        4.0     79.000000   58.000000  1755.000000
# 82         22.0        6.0    232.000000  112.000000  2835.000000
#            24.0        4.0    140.000000   92.000000  2865.000000
#            25.0        6.0    181.000000  110.000000  2945.000000
#            26.0        4.0    156.000000   92.000000  2585.000000
#            27.0        4.0    138.500000   88.500000  2778.750000
#            28.0        4.0    116.000000   83.500000  2615.000000
#            29.0        4.0    135.000000   84.000000  2525.000000
#            31.0        4.0    107.333333   78.333333  2421.666667
#            32.0        4.0    123.333333   82.333333  2308.333333
#            34.0        4.0    110.000000   79.000000  2320.000000
#            36.0        4.0    113.000000   78.200000  2168.000000
#            37.0        4.0     91.000000   68.000000  2025.000000
#            38.0        4.5    137.250000   70.500000  2275.000000
#            44.0        4.0     97.000000   52.000000  2130.000000
#
#                  acceleration    origin
# model_year mpg
# 81         34.7     14.900000  1.000000
#            35.1     16.100000  3.000000
#            37.0     19.400000  3.000000
#            37.7     17.300000  3.000000
#            39.0     16.400000  1.000000
#            39.1     16.900000  3.000000
# 82         22.0     14.700000  1.000000
#            24.0     16.400000  1.000000
#            25.0     16.400000  1.000000
#            26.0     14.500000  1.000000
#            27.0     17.375000  1.000000
#            28.0     19.100000  1.000000
#            29.0     16.000000  1.000000
#            31.0     17.733333  1.666667
#            32.0     13.733333  2.333333
#            34.0     17.450000  2.000000
#            36.0     14.920000  2.000000
#            37.0     18.200000  3.000000
#            38.0     15.725000  2.000000
#            44.0     24.600000  2.000000
#
# [20 rows x 6 columns]

# %%
df[df.cylinders<=4].sort('mpg', ascending=True)[:5]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 110   18          3            70          90    2124          13.5
# 75    18          4           121         112    2933          14.5
# 119   19          4           121         112    2868          15.5
# 70    19          3            70          97    2330          13.5
# 111   19          4           122          85    2310          18.5
#
#      model_year  origin         car_name
# 110          73       3        maxda rx3
# 75           72       2  volvo 145e (sw)
# 119          73       2      volvo 144ea
# 70           72       3  mazda rx2 coupe
# 111          73       1       ford pinto

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
df['car_name']
# Out:
# 0              chevrolet chevelle malibu
# 1                      buick skylark 320
# 2                     plymouth satellite
# 3                          amc rebel sst
# 4                            ford torino
# 5                       ford galaxie 500
# 6                       chevrolet impala
# 7                      plymouth fury iii
# 8                       pontiac catalina
# 9                     amc ambassador dpl
# 10                   dodge challenger se
# 11                    plymouth 'cuda 340
# 12                 chevrolet monte carlo
# 13               buick estate wagon (sw)
# 14                 toyota corona mark ii
# 15                       plymouth duster
# 16                            amc hornet
# 17                         ford maverick
# 18                          datsun pl510
# 19          volkswagen 1131 deluxe sedan
# 20                           peugeot 504
# 21                           audi 100 ls
# 22                              saab 99e
# 23                              bmw 2002
# 24                           amc gremlin
# 25                             ford f250
# 26                             chevy c20
# 27                            dodge d200
# 28                              hi 1200d
# 29                          datsun pl510
#                      ...
# 362                   chevrolet cavalier
# 363             chevrolet cavalier wagon
# 364            chevrolet cavalier 2-door
# 365           pontiac j2000 se hatchback
# 366                       dodge aries se
# 367                      pontiac phoenix
# 368                 ford fairmont futura
# 369                  volkswagen rabbit l
# 370                   mazda glc custom l
# 371                     mazda glc custom
# 372               plymouth horizon miser
# 373                       mercury lynx l
# 374                     nissan stanza xe
# 375                         honda accord
# 376                       toyota corolla
# 377                          honda civic
# 378                   honda civic (auto)
# 379                        datsun 310 gx
# 380                buick century limited
# 381    oldsmobile cutlass ciera (diesel)
# 382           chrysler lebaron medallion
# 383                       ford granada l
# 384                     toyota celica gt
# 385                    dodge charger 2.2
# 386                     chevrolet camaro
# 387                      ford mustang gl
# 388                            vw pickup
# 389                        dodge rampage
# 390                          ford ranger
# 391                           chevy s-10
# Name: car_name, dtype: object
